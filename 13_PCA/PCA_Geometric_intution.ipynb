# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# this photographer is trying capture the 3d or multi-dimension information 2d
#
#
# mean he try capture the photo 3d time and want to publish in news paper that will be 2d dimenstional

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # THIS FOR FEATURE SELECTION NOT FOR `PCA`
#
#
# ![image-2.png](attachment:image-2.png)
#
# we plot our data point check the on `grocary shop on the Y` and `no of room on the X`
#
# we look at data point `X` for room which show higher spread of the data i.e `d` compare to grocery distance `d'`
#
# which mean the `room` show the hgiher variance
#
#
#
# THIS HOW THE `FEATURE SELECTION METHOD WORKS` AND WE DROP THE LESS VARIANCE FEATURES FROM THE DATA
#
# but what if the both FEATURES ARE EQUALLY IMPORTANT WE CAN DROP OR IGNORE THE FEATURE
# IN THAT CASE WE NEED TO IMPLEMENT THE `PCA`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if we look this data both feature are equally important and also mathematically both feature has the same variance because the are linearyly correlated

# %% [markdown]
# # implement the feature extraction method to solve above problem using PCA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# HERE IN pca what we tried
# we try to shift the orignal feature in different direction tried to cal the variance
#
# in  above orignal distribution of the data
# varinace or spread of the data for the room and no.of wash room is same
#
# but we shift or rotated the our axis and then we cal the spread or variace of the data
#
# after shiting for the no.of wash room the variance is very low compare to the no.of room
#
# so the new shifted axis will be the our principle component (room--->PC1 because which explain the more variance wash room will be the PC2 because less variance compare to room)

# %% [markdown]
# # why variance is important
# because it show the  magnitude and direction of the pca

# %% [markdown]
# why not mean because the mean do not tell the spread and direction of the spread of the data
#
# it tell the central tendency of the data which
# means the central of the your data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# in above both example the mean is zero

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# spread is propational to the variance but not exact variance
#
# spread we take the mod of the data it mean the your function in non differentiable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# from this image if we look the projection of the data point on the y axis which show the low vairance which will make the diffifculty to the model to classify the data point
#
# but if we look at x axis then vairance is higher it mean we can easy classify this data point
#
# thats why variance is important
