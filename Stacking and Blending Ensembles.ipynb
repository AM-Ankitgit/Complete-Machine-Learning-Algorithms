# %% [markdown]
# <h1>Stacking<h1/>

# %% [markdown]
# Stacking is similar to vating ensemble ,it extend the idea voting  ensemble

# %%
data set

iq ,cgpa, package


Step-1:
train the base Model on set
M1 :Linear Reg
M2 :DT(regressor)
M3 :KNN(Regressor)

new data set 

step-2:
  package pred_Lr,pred_DT,pred_KNN

this new data we train on the our meta Model 

meta_model  = RF()

# %%
what is differnce between the bagging and boosting and staging

in bagging and boosting >>>> BASE MODEL Will be Same 
                        >>>> and we do the aggriation output of the base ModuleNotFoundError

in staging used the BASE MODEL Will be Different (kind of Voting Ensemble)
and final output will be from training the output of base model

# %% [markdown]
# what is problem in Staging
# - we are doing training and prediction on same data
# it lead to the overfiting

# %% [markdown]
# # Solution :
# - 1) Hold Out Method : it is call as the BLENDING Method
# - 2) k-Fold Method : it is call as the stacking method

# %% [markdown]
# Hold Out Method or BLENDING Method
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # k-Fold Method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step -1: k-fold data set
# then train each model on k-fold
# the get the prediction from the remainig black of k-fold
#
# so here model will train on the 600 row from each k-fold and predction on 200 row
#
# 200+200+200+200
# so total prection point for the one base model is 800
#
# new  data set
# pred_lr, pred_dt, pred_knn package(target_variable)
# 1
# 2
# .
# .
# .
# 800
#
#
# now META MODEL Will train on the new dataset(prediction we got from k-kold)
# Meta model is train:
# now again train base model on training dataset we will get three base model
#
# meta_model(RF)(its already train model on from the out of base model of k-fold)
# model1(trained model from training set)
# mode12(trained model from training set)
# model3(trained model from training set)
#
# now we have 4 model and now we can do the predition from the test data set
