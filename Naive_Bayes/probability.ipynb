# %% [markdown]
# # Union
#
# {1,2}∪{2,3}   = {1,2,3}
#
# - The union of two sets is a set containing all elements that are in A
#  or in B

# %% [markdown]
# # intersection
# - The intersection of two sets A and B
# , denoted by A∩B
#  - consists of all elements that are both in A
#  and
#  B
# - For example, {1,2}∩{2,3}={2}

# %% [markdown]
# Conditional probability is known as the possibility of an event or outcome happening, based on the existence of a previous event or outcome

# %% [markdown]
# <h1>Independent Event</h1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# here INTERSECTION of A and B is the independent of occurrence of event A and B
# it does not affect the occurrence  of previous event
#
# ![image.png](attachment:image.png)

# %% [markdown]
# here prob of A for given B , so is already occurred
# intersection of a and b divide by total b
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mutually Exclusive Event

# %% [markdown]
# ![image.png](attachment:image.png)
#
# means the both even cannot existed together
# mean when you toss the coin , it will never give the head and tail at together
# eg. if we are driving the car. either you take the right turn or left ,but not will never take the both turn at same time
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Bayes Theorems
#
# prob of A for Given B
# ![image.png](attachment:image.png)
#
# why the p(B)!=0 because the prob of B is given it mean it will never zeros
#
#
# based on conditional probability
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # ![image.png](attachment:image.png)
