# %% [markdown]
# # what is probability and likelihood(शक्यता)

# %% [markdown]
# if we have coin
# if already know the parameter (means distribution here is Bernoulli distribution mean p value)
#
# ## `probability`
# if we know the distribution and want to chance of getting then we called as the probability
#
#
# ## `likelihood` :
# it opposite to the probability :
# mean if we have even occurance
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # how to answere the difference between the likelihood and probability (for discrete)
#
# suppose we have bag which has 3-red ,2 green ball
#
# so it fall the bernaulli distrbution
#
# if we already know the chance of getting of green ball is 2/5
#
# if we want know what is chance of getting for the red ball is it 3/5  then it is called as the `probability`
#
# here we go from parameter to event
#
#
# if we draw the ball from bag 5 times and got same ball eg. green
#
# then what is  chance of getting for the green ball
#
# is (2/5)*5 it will give the small number
# this process called as the `likelihood`
# event to parameter

# %% [markdown]
# # for continuous (normal distribution)
# ![image.png](attachment:image.png)
#
#
# `probability` : here we try to find the chance of getting age in between the 170 to 180 (by area under curve)
#
# `likelihood` :
# here if we take age 100 what is chance the that age will follow the normal distribution

# %% [markdown]
# ![image.png](attachment:image.png)
