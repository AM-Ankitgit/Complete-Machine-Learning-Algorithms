# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Voting Ensemble
# - base model different
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Stacking

# %% [markdown]
# - gives the weighted
# ![image.png](attachment:image.png)

# %% [markdown]
# Bagging
# - boostrapped aggregation
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
