# %% [markdown]
# # What is tensor
# Tensors are mathematical objects that generalize scalars,
# vectors and matrices to higher dimensions.

# %%
it is way of storing the data  (data Structure)
Tensors are the container where we store the numbers

# %%
In short, a single-dimensional tensor can be represented as a vector. A two-dimensional tensor, 
as you may have guessed, can be represented as a matrix.

# %%
Even though it’s easy to generalize tensors as multi-dimensional matrices ranging from zero to N dimensions, 
it is important to remember that tensors are dynamic. That is, tensors will transform when interacting with other mathematical entities.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Important
# difference between the dimension of tensor and vector
# [1,2,3,4]
# for vector dim = 4D
# for Tensor dim = 1D
#
# if you want 1D Tensor then it the collection of 0D Tensor
# if want Vector then it is the collection scaler
# if matrix then it collection of Vector

# %% [markdown]
# it has two axis i.e rank=2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
